# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

df = pd.read_csv("Final_data.csv")  # Load dataset into a pandas dataframe
df.dropna(inplace = True)

df.head()
# Out:
#    YEAR  MONTH  DAY  TOTALDEMAND_x   MAX  ACCMAX  RAIN  RAINPERIOD  SOLAR  \
# 0  2010      1    1    7793.463681  29.6     1.0   0.2         1.0   14.6
# 1  2010      1    1    7793.463681  29.6     1.0   0.2         1.0   14.6
# 2  2010      1    2    8012.314097  29.5     1.0   0.0         1.0   18.4
# 3  2010      1    2    8012.314097  29.5     1.0   0.0         1.0   18.4
# 4  2010      1    3    7393.354514  21.0     1.0  15.2         1.0    7.3
#
#    TOTALDEMAND_y        RRP  FORECASTDEMAND  OUTPUT  QUANTITY  \
# 0    7796.317872  20.364894     7747.906211    1.53       1.0
# 1    7796.317872  20.364894     7747.906211    1.53       1.0
# 2    8017.459792  20.478125     7773.818583    1.53       1.0
# 3    8017.459792  20.478125     7773.818583    1.53       1.0
# 4    7399.899583  20.277083     7462.384786    1.53       1.0
#
#    QUANTITYMONTHCUM  QUANTITYTOTALCUM  OUTPUTMONTHCUM  OUTPUTTOTAL
# 0               1.0              20.0            1.53        31.86
# ...

# %%
#X = df.iloc[:,[3,5,9,16]]
#y = df.iloc[:,10]

X = df.drop(['YEAR', 'MONTH', 'DAY', 'TOTALDEMAND_x', 'ACCMAX', 'RAINPERIOD', 'SOLAR', 'TOTALDEMAND_y', 'OUTPUT', 'QUANTITY', 'QUANTITYMONTHCUM', 'QUANTITYTOTALCUM', 'OUTPUTMONTHCUM'], axis=1)
y = df['FORECASTDEMAND']

# split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create a Random Forest classifier object
rf = RandomForestRegressor(n_estimators=100)

# Fit the model to the training data
rf.fit(X_train, y_train)

# Make predictions on the testing data
y_pred = rf.predict(X_test)

# Evaluate the model's accuracy
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-c0d81fd147f6> in <module>
#      18
#      19 # Evaluate the model's accuracy
# ---> 20 accuracy = accuracy_score(y_test, y_pred)
#      21 print('Accuracy:', accuracy)
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     200
#     201     # Compute accuracy for each possible representation
# --> 202     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
# ...
